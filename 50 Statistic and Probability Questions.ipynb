# %% [markdown]
# https://www.projectpro.io/article/statistic-and-probability-interview-questions-for-data-science/483

# %% [raw]
# Topics:
#
#     Descriptive Statistics
#
#     Measures of central tendency
#
#     Covariance
#
#     Correlation
#
#     Central Limit Theorem
#
#     Types of Probability Distributions
#
#     Hypothesis Testing
#
#     Type I and Type II Errors
#
#     Statistical Models -- Linear Regression, Logistic Regression
#
#     Dimensionality Reduction

# %% [markdown]
# ## Q1.  What is the difference between quantitative and qualitative data?

# %% [raw]
# Quantitative data is data defined by a numeric value.
#
# Qualitative data is non-numeric information, it describes qualities or characteristics.

# %% [markdown]
# ## <font color='blue'> Q2. Name three different types of encoding techniques when dealing with qualitative data. </font>

# %%
One Hot Encoding [0,1,0,0]

Label Encoding [1] or [2] or [3] or [4]
 
Binary Encoding

# %% [markdown]
# ## <font color='green'> Q3. Explain the bias-variance trade-off. </font>

# %% [raw]
# The bias-variance trade-off is the trade-off between the error introduced by the bias and the error introduced by a model’s variance. A highly biased model is too simple and doesn’t fit well enough to the training data.
#
# A model with high variance fits exceptionally well to the training data and cannot generalize outside the data it was trained on. The bias-variance trade-off involves finding a sweet spot to build a machine learning model that fits well enough onto the training data and can generalize and perform well on test data.

# %% [markdown]
# ## <font color ='red'> Give examples of machine learning models with high bias </font>

# %% [raw]
# Linear Regression, Logistic Regression

# %% [markdown]
# ![Screenshot%202022-07-16%20at%208.42.39%20PM.png](attachment:Screenshot%202022-07-16%20at%208.42.39%20PM.png)

# %%
SVM: low bias

# %% [markdown]
# ## <font color='red'> Q6 What is sensitivity and specificity in machine learning with an example? </font>

# %% [raw]
# sensitivity (recall) = TP/ TP + FN
#
#
# speficity = 1 - FPT = TN / TN + FP ==> TNR (true negative rate)

# %% [raw]
# If we build a machine learning model to predict the presence of a disease in a person,
#
# then sensitivity is the true positive rate.
# The proportion of people who have the disease that received a positive prediction is called sensitivity.
#
# The proportion of people who don’t have the disease who received a negative prediction is called specificity.

# %% [markdown]
# ## Q7.What is the difference between a Type I and Type II error?

# %% [raw]
# Type I : reject H0 when it is True (alpha = significance level)
#
# Type II : Do not reject H0 when it is not True (beata = 1 - power)

# %% [markdown]
# ## Q8. What are the assumptions made when building a linear regression model?

# %% [raw]
# 1. There is a linear relationship between the dependent variable (Y) and the independent variable (X).
#
# 2. Homoscedasticity: equal variance ( the variation in the residuals is similar at each point across the model.)
#
# 3. NO multicollinearity: the independent variables aren’t highly correlated with each other
#
# 4. The residuals follow a normal distribution and are independent of each other.

# %% [markdown]
# ## Q9.  Name three different types of validation techniques.

# %%
Train-test split

Leave one out Cross Validation

K-fold Cross validation

# %% [markdown]
# ## Q10. What is multicollinearity? How does it impact the performance of a regression model?

# %% [raw]
# Multicollinearity occurs when two or more independent variables in the dataset are highly correlated with each other.
#
# Multicollinearity is a problem because it undermines the statistical significance of an independent variable.

# %% [markdown]
# ## Q11. What is regularization? Why is it done?

# %% [raw]
# Regularization refers to techniques that are used to calibrate machine learning models in order to minimize the adjusted loss function and prevent overfitting.
#
# Adding a regularization term to the loss function.
#
# Loss function:

# %%
Lasso: adds penalty equal to the absolute value of the magnitude of coefficient

# %% [markdown]
# ![Screenshot%202022-07-17%20at%2010.26.22%20AM.png](attachment:Screenshot%202022-07-17%20at%2010.26.22%20AM.png)

# %% [raw]
# λ is the regularization parameter. It controls the trade-off between model complexity and model fitting.
#
# If λ is too small: there is almost no regularization. It doesn’t shrink the parameter too much → prone to be overfitting
#
# If λ is too large: it will shrink the parameters too much, all the parameters will be close to zero → prone to be underfitting
#
# Usually we use cross-validation to choose the best λ.

# %% [markdown]
# ### Regularization Techniques:

# %% [markdown]
# ![Screenshot%202022-07-17%20at%2010.28.54%20AM.png](attachment:Screenshot%202022-07-17%20at%2010.28.54%20AM.png)

# %% [markdown]
# ![Screenshot%202022-07-17%20at%2010.29.29%20AM.png](attachment:Screenshot%202022-07-17%20at%2010.29.29%20AM.png)

# %% [markdown]
# ![Screenshot%202022-07-17%20at%2010.30.36%20AM.png](attachment:Screenshot%202022-07-17%20at%2010.30.36%20AM.png)

# %% [raw]
# For lasso regression, the optimal point is likely to be on the corner, which means that some parameters will be 0.
#
# For ridge regression, the optimal point can lies in any where in the constraints boundary, so the optimal point is not likely to contain 0 values.

# %% [markdown]
# ### SEE ALSO Q27 below

# %% [markdown]
# ## Q12. What does the value of R-squared signify?

# %% [raw]
# The proportion of variance explained by the model
#
# how much variation of a dependent variable is explained by the independent variable(s) in a regression model.

# %% [markdown]
# ## Adjusted R -squared

# %%
Adjusted R-squared is a modified version of R-squared

The adjusted R-squared shows whether adding additional predictors improve a regression model or not.

# %% [markdown]
# ![Screenshot%202022-07-16%20at%2010.39.45%20PM.png](attachment:Screenshot%202022-07-16%20at%2010.39.45%20PM.png)

# %% [markdown]
# ## Q13. What is the Central Limit Theorem?

# %% [raw]
# When the sample size is large enough, the distribution of the sample means will follow the Normal Distribution.
#
# No matter what the distribution of the population is.

# %% [markdown]
# ### The law of large numbers

# %% [raw]
# an observed sample mean from a smaple will be close to the population mean when the sample size gets larger

# %% [markdown]
# ## <font color ='red'> 14. What is the five-number summary in statistics?  </font>

# %%
The maximum, minimum, the first quartile, the third quartile, and the median

These five values can give us a rough idea of what our variables look like. 

Can be visualized easily through a box plot.

# %% [markdown]
# ## <font color ='blue'> Q15. Explain the process of bootstrapping. </font>

# %% [raw]
# Repeatedly sampling a dataset with random replacement.
#
# Use the results obtained from the samples to infer results for the population.

# %% [markdown]
# ## Bagging
#
# Bootstrap aggregation, is an ensemble ML technique, which is mainly applied in classification and regression.
#
# In increases the accuracy of models and reduce the overfitting.
#
# Advantage:
#
#       reduce overfitting
#
# Disadvantage:
#
#      computationally expensive
#
#      more bias

# %% [markdown]
# ## Boosting
#
# an ensemble ML technique that learns from previous predictors mistakes.
#
# Weak learners are buit in a sequence.
#
# Advantage:
#
#         Reduce overfitting and bias
#
# Disadvantage:
#
#         Sensitive to outliers

# %% [markdown]
# ### Boosting

# %% [raw]
#  In boosting, a random sample of data is selected, fitted with a model and then trained sequentially.

# %% [markdown]
# ## Differences

# %% [raw]
# In bagging method, all individual models are in parallel and are built separately.
#
# In boosting, each mode will build in a sequence, based on previous models.

# %% [markdown]
# ## <font color='blue'> Q 16. Ways to mitigate overfitting. </font>

# %%
Cross validation, e.g., K -fold cross validation

L1 / L2 regularization

Collect more samples

Feature selection

Early stopping

# %% [markdown]
# ## Q17. How do you deal with missing data?

# %% [raw]
# 1. Delete missing values
#
# 2. Impute missing values with mean/ median/ mode
#
# 3. Replacing the missing values with a constant
#
# 4. Building a machine learning model to predict the missing value based on other values in the dataset

# %% [markdown]
# ## Q 18. What are confounding variables?

# %%
A confounding variable is a factor that affects both the dependent and independent variables.

# %% [markdown]
# ## Q 19.  What is A/B testing? Explain with an example.

# %% [raw]
# A/B testing is the process of comparing two versions of something and measuring the difference.
#
# For example, a company wants to test two versions of their landing page with different backgrounds to understand which version drives conversions.
# A controlled experiment is created, and two variations of the landing page are shown to different sets of people.

# %% [markdown]
# ## <font color ='red'> Q20. Explain three different types of sampling techniques. </font>

# %% [raw]
# Simple random sampling:
# The individual is selected from the true population entirely by chance, and every individual has an equal opportunity to get selected.
#
#
# Stratified sampling:
# The population is first divided into multiple groups that share similar characteristics, and each group is sampled in equal sizes. This is done to ensure equal representation of all sub-groups.
#
#
# Systematic sampling:
# Individuals are selected from the sampling frame at regular intervals.
# For example, every 10th member is selected from the sampling frame.

# %% [markdown]
# ##  <font color ='red'> Q22 Explain the terms confidence interval and confidence level. </font>

# %% [raw]
# Confidence interval is a range of values where you know the true population parameter will lie within this range
# for a certain proportion of times. That proportion is the confidence level.

# %% [markdown]
# ## Q23. What is p-value?

# %% [raw]
# The probability of obtaining results at least as extreme as the obsevered results of a statistical hypothesis test.
#
# Layman Language:
#
# Assume we have to samples, A and B. And we obsever two different sample means for A and B.
# We want to know the probability of seeing this difference due to random chance. That is the p-value.

# %% [markdown]
# ## Power

# %%
The probability of a test can correctly reject the false HO.

# %% [markdown]
# ## Q 24. What is standardization?
# ## Under which circumstances should data be standardized?

# %% [raw]
# Standardization is the process of putting different variables on the same scale.
# After standardization, all variables will follow a standard normal distribution.
#
# Standardization can also used as a pre-processing technique before feeding data into machine models.
# If can also give us a better idea of outliers, as it is easy to identify values that are 2-3 std away from the mean.

# %% [markdown]
# ## Q26. What are some properties of a normal distribution?
#
# ## Give some examples of data points that follow a normal distribution.

# %% [raw]
# Properties:
#
#     The mean, median, and mode in a normal distribution are the same (very close to each other).
#
#     The distribution is symmetric about the mean.
#
#     The distribution plot is bell-shaped.

# %% [raw]
# Examples:
#
#     The heights of adults
#
#     the scores on a test given a large class
#
#     errors in measurements

# %% [markdown]
# ## <font color ='red'> Q27 When is it a good idea to use the mean as a measure of central tendency? <font>

# %% [raw]
# When data follows a normal distribution.
#
# However, if data is skewed, it is better to use the median as a measure of central tendency.

# %% [markdown]
# ## What is Central tendency?

# %% [raw]
# Central tendency is defined as “the statistical measure that identifies a single value as representative of an entire distribution.”[2] It aims to provide an accurate description of the entire data.

# %% [markdown]
# ## Q27.  Explain the difference between ridge and lasso regression.

# %% [raw]
# Ridge regression or L2 regression, adds the sum of the square of weights as a penalty to the model’s cost function.
#
# Lasso regression or L1 regression, adds the sum of the absolute weights to the model’s cost function.
#
# Lasso regression can also be used as a feature selection technique, as it can pull feature weights down to zero and eliminate variables that aren’t necessary.

# %% [markdown]
# ## Q28.  What is the law of large numbers? Provide an example.

# %% [raw]
# Aas the number of identically distributed, randomly generated variables increases, their sample mean (average) approaches their theoretical mean.

# %% [raw]
# Example:
#
#     For example, if we toss a coin 1000 times, the probability of seeing heads in the coin tosses will be closer to 0.5 than if we tossed the coin 100 times.

# %% [markdown]
# ## Q29. How can outliers be identified?

# %%
1. Visulisation method: scatterplot, boxplot
    
2. IQR

3. Z-scores (represents the number of std a value away from the mean)

# %% [markdown]
# ## Q30. When is it better to use an F1 score over accuracy to evaluate a model?

# %% [markdown]
# The F1 score is the harmonic mean of a model’s precision and recall.
#
# <font color ='blue'> In the case of imbalanced datasets, the F1 score provides us a better measure of model performance than accuracy. </font>

# %% [markdown]
# ## Q31. What is selection bias?

# %% [raw]
# When obtaining samples from the population, selection bias is a bias occurs when randomization isn’t completely achieved.
#
# This means that the samples won’t represent the true population, as a subset of the true population is left out.

# %%
Q41. different types of selection bais.

# %% [markdown]
# ## Q32. What are some ways to overcome an imbalanced dataset?

# %% [raw]
# 1. Under-sampling
# Keeping all samples from minority group, and randomly selecting an equal number of samples from the majority group.
#
# 2. Over-sampling
# Keeing all samples from majority group, and randomly duplicating samples in minority group to let the numbler of samples in it equal to the one of majority group.

# %% [markdown]
# ### Harm of Imbalanced data

# %% [markdown]
# An imbalanced dataset has an over-representation of the majority group and under-representation of the minority class. And may lead to incorrect predictions.

# %% [markdown]
# ## Q33. When should you use a t-test and a z-test?

# %%
Z-test:
    population variance is known and the sample size is large
    
T-test:
    the population variance is unknown or the sample size is small

# %% [markdown]
# ## <font color ='red'> Q34.  What is the difference between a homoscedastic and heteroscedastic model? </font>

# %%
Homoscedastic model:
    the variance of the residuals is the same or similar
    
Heteroscedastic model:
    the variance of the results is unequal

# %% [markdown]
# ## Q 35. Which model generally performs better in making predictions?
#
# # random forests or decision trees? Explain why.

# %% [raw]
# Random forest.
#
# Random forest is an ensemble ML technique that uses Decision Trees as the base learner. It can effectively reduce the overfitting compared with the decision trees.

# %% [markdown]
# ## <font color ='blue'> Q 36. How can overfitting be detected when building a prediction model? </font>

# %% [raw]
# We can identify overfitting by looking at validation metrics, like loss or accuracy.
#
# by using K-Fold cross-validation for training and testing

# %% [markdown]
# ## <font color ='blue'> Q37. Is it possible for a poor classification model to have high accuracy? If so, why does this happen? </font>

# %% [markdown]
# Accuracy = (TP + TN) / (TP + FP + TN +FN)
#
# It is possible.
#
# A poor model that simply predicts the majority class can perform well in terms of accuracy.
#
# Example, if 90% of the samples in the dataset tested negative for disease and 10% tested positive. A model that predicts all negative will have a 90% accuracy. But the performance of the model is still poor.

# %% [markdown]
# ## Q38. There is a right-skewed distribution with a median of 70. What can we conclude about the mean of this variable?

# %%
The mean of this variable will be over 70, as the positive skew will pull the mean along with it.

# %% [markdown]
# ![Screenshot%202022-07-17%20at%204.17.47%20PM.png](attachment:Screenshot%202022-07-17%20at%204.17.47%20PM.png)

# %% [markdown]
# ## Q 39. What is a correlation coefficient?

# %% [raw]
# A correlation coefficient is an indicator of how strong the relationship between two variables is.
#
# A coefficient near +1 indicates a strong positive correlation,
# a coefficient of 0 indicates no correlation,
# and a coefficient near -1 indicates a strong negative correlation.

# %% [markdown]
# ## <font color ='red'>  Q40 What does it mean if an independent variable has high cardinality? How does this impact model performance? </font>

# %% [raw]
# Cardinality refers to the number of categories a single categorical variable has.
#
# If a variable has high cardinality, it means that it has many different types associated with it.
# This can negatively impact model performance if not correctly encoded.

# %% [markdown]
# ## Q 41.  What are the different types of selection bias? Explain them.

# %%
Q 31

# %% [raw]
# Sampling bias:
# It is cased by non-random sampling.
# For example, if you were to survey all university students to understand their view on gender disparity but only surveyed female students. This would introduce a bias into the model and wouldn’t provide a complete picture of the true population.
#
# Volunteer bias:
# Also known as self-selection bias, volunteer bias is a systematic error due to differences between those who choose to participate in studies and those who do not.
#
# Exclusion Bias:
# Exclusion bias happens when the researcher intentionally removes some subgroups from the sample population.
#
# Time-interval bias:
# This is bias caused by selecting observations that only cover a specific range of time.

# %% [markdown]
# ## <font color='red'> Q42.  What are the assumptions made when building a logistic regression model? </font>

# %%
No multicollinearity among independent variables.

Absence of outliers that can strongly impact the model.

There should be no relationship between the residuals and the variable.

logistic regression typically requires a large sample size

# %% [markdown]
# ### Compared with Linear Regression

# %% [raw]
# Logistic regression does not make many of the key assumptions of linear regression and general linear models that are based on ordinary least squares algorithms – particularly regarding linearity, normality, homoscedasticity, and measurement level.
#
# First, logistic regression does not require a linear relationship between the dependent and independent variables.
# Second, the error terms (residuals) do not need to be normally distributed.
#
# Third, homoscedasticity is not required.
#
# Finally, the dependent variable in logistic regression is not measured on an interval or ratio scale.

# %% [markdown]
# ## <font color ='red'> Q43. Explain the bagging technique in random forest models. </font>

# %% [raw]
# Bagging stands for bootstrap aggregation.
#
# In random forests, the dataset is sampled multiple times using the bootstrap technique with replacement.
#
# Weak learners are the decision trees, they are trained independently on each sample with different features to split on at each node. Finally, the average or majority class prediction is provided as output to the user.

# %% [raw]
# Bagging is an ensemble algorithm that fits multiple models on different subsets of a training dataset, then combines the predictions from all models.

# %% [markdown]
# ## Q44. Describe three error metrics for a linear regression model.

# %%
MSE: mean squared error
    
MAE: mean absolute error
    
RMSE: the root mean of squared error

# %% [markdown]
# ## <font color ='blue'> Q 45. Explain the impact of seasonality on a time-series model. </font>

# %% [raw]
# When building a time-series model, seasonality is a factor that can impact the model’s performance.
#
# These are cycles that repeat over a certain time and need to be accounted for in the model that is being built. Otherwise, there is a risk of making inaccurate predictions.
#
# For example, let’s say you want to build a model that predicts the number of hoodies sold in the next few months. If you only use data from the beginning of the year to make the prediction and don’t take into account the previous year, you won’t account for seasonal variations in buying patterns. People would buy lesser hoodies in March and April as they did in February because the weather is getting warmer, which isn’t accounted for by the machine learning model.

# %% [markdown]
# ## Q 46. What is the default threshold value in logistic regression models?

# %%
0.5

# %% [markdown]
# ## Q. 47  Is it possible to change this threshold? Describe a situation that might require you to control the threshold value.

# %% [markdown]
# Yes, it is possible to change the threshold of a logistic regression model.
#
# For example, in situations where we want to identify more true positives and build a model with high sensitivity, we can reduce the threshold value so that a slightly lower than 0.5 can also be considered a positive prediction.

# %% [markdown]
# ## Q 48. Differentiate between univariate and bivariate analysis.

# %%
The univariate analysis only summarizes one variable at a time. 
Measures of variance and central tendency are examples of univariate analysis. 


Bivariate analysis analyzes the relationship between two variables, such as correlation or covariance.

# %% [markdown]
# ## Q 49Python code to calculate correlation

# %%
np.corrcoef(x,y)

# %% [markdown]
# ## Q 50 “If there is sufficient evidence to reject the null hypothesis at a 5% significance level, then there is sufficient evidence to reject it at a 1% significance level.” Is this statement true or false, and explain why.

# %% [raw]
# False.
#
# Since we don’t know the actual p-value, we can’t tell if the null hypothesis will be rejected.
#
# If the p-value was smaller than 0.01, there is sufficient evidence to reject the null hypothesis at a 1% significance level.
# However, if the p-value was around 0.04, it wouldn’t be possible to reject the null hypothesis at a 1% significance level.
